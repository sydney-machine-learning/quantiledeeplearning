# %%
# Import Libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
Bitcoin = pd.read_csv('data/coin_Bitcoin.csv')
Ethereum = pd.read_csv('data/coin_Ethereum.csv')

# %%
# Understand Data

# %%
Bitcoin
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %%
Bitcoin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2991 entries, 0 to 2990
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SNo        2991 non-null   int64
#  1   Name       2991 non-null   object
#  2   Symbol     2991 non-null   object
#  3   Date       2991 non-null   object
#  4   High       2991 non-null   float64
#  5   Low        2991 non-null   float64
#  6   Open       2991 non-null   float64
#  7   Close      2991 non-null   float64
#  8   Volume     2991 non-null   float64
#  9   Marketcap  2991 non-null   float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 233.8+ KB

# %%
# No null values

# %%
Ethereum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2160 entries, 0 to 2159
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SNo        2160 non-null   int64
#  1   Name       2160 non-null   object
#  2   Symbol     2160 non-null   object
#  3   Date       2160 non-null   object
#  4   High       2160 non-null   float64
#  5   Low        2160 non-null   float64
#  6   Open       2160 non-null   float64
#  7   Close      2160 non-null   float64
#  8   Volume     2160 non-null   float64
#  9   Marketcap  2160 non-null   float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 168.9+ KB

# %%
Ethereum
# Out:
#        SNo      Name Symbol                 Date         High          Low  \
# 0        1  Ethereum    ETH  2015-08-08 23:59:59     2.798810     0.714725
# 1        2  Ethereum    ETH  2015-08-09 23:59:59     0.879810     0.629191
# 2        3  Ethereum    ETH  2015-08-10 23:59:59     0.729854     0.636546
# 3        4  Ethereum    ETH  2015-08-11 23:59:59     1.131410     0.663235
# 4        5  Ethereum    ETH  2015-08-12 23:59:59     1.289940     0.883608
# ...    ...       ...    ...                  ...          ...          ...
# 2155  2156  Ethereum    ETH  2021-07-02 23:59:59  2155.596496  2021.824808
# 2156  2157  Ethereum    ETH  2021-07-03 23:59:59  2237.567155  2117.590013
# 2157  2158  Ethereum    ETH  2021-07-04 23:59:59  2384.286857  2190.837703
# 2158  2159  Ethereum    ETH  2021-07-05 23:59:59  2321.922836  2163.041394
# 2159  2160  Ethereum    ETH  2021-07-06 23:59:59  2346.294874  2197.919385
#
#              Open        Close        Volume     Marketcap
# ...

# %%
# changing the format of Date in Bitcoin dataset
Bitcoin["Date"]=pd.to_datetime(Bitcoin["Date"], format='%Y-%m-%d %H:%M:%S').dt.strftime('%Y-%m-%d')
Bitcoin
# Out:
#        SNo     Name Symbol        Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03    108.127998     79.099998
# ...    ...      ...    ...         ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06  35038.536363  33599.916169
#
#               Open         Close        Volume     Marketcap
# 0       134.444000    144.539993  0.000000e+00  1.603769e+09
# ...

# %%
# changing the format of date in Ethereum Dataset
Ethereum["Date"]=pd.to_datetime(Ethereum["Date"], format='%Y-%m-%d %H:%M:%S').dt.strftime('%Y-%m-%d')
Ethereum
# Out:
#        SNo      Name Symbol        Date         High          Low  \
# 0        1  Ethereum    ETH  2015-08-08     2.798810     0.714725
# 1        2  Ethereum    ETH  2015-08-09     0.879810     0.629191
# 2        3  Ethereum    ETH  2015-08-10     0.729854     0.636546
# 3        4  Ethereum    ETH  2015-08-11     1.131410     0.663235
# 4        5  Ethereum    ETH  2015-08-12     1.289940     0.883608
# ...    ...       ...    ...         ...          ...          ...
# 2155  2156  Ethereum    ETH  2021-07-02  2155.596496  2021.824808
# 2156  2157  Ethereum    ETH  2021-07-03  2237.567155  2117.590013
# 2157  2158  Ethereum    ETH  2021-07-04  2384.286857  2190.837703
# 2158  2159  Ethereum    ETH  2021-07-05  2321.922836  2163.041394
# 2159  2160  Ethereum    ETH  2021-07-06  2346.294874  2197.919385
#
#              Open        Close        Volume     Marketcap
# 0        2.793760     0.753325  6.741880e+05  4.548689e+07
# ...

# %%
Bitcoin.Close # currency is in USD
# Out:
# 0         144.539993
# 1         139.000000
# 2         116.989998
# 3         105.209999
# 4          97.750000
#             ...
# 2986    33897.048590
# 2987    34668.548402
# 2988    35287.779766
# 2989    33746.002456
# 2990    34235.193451
# Name: Close, Length: 2991, dtype: float64

# %%
Bitcoin.describe()
# Out:
#                SNo          High           Low          Open         Close  \
# count  2991.000000   2991.000000   2991.000000   2991.000000   2991.000000
# mean   1496.000000   6893.326038   6486.009539   6700.146240   6711.290443
# std     863.571653  11642.832456  10869.032130  11288.043736  11298.141921
# min       1.000000     74.561096     65.526001     68.504997     68.431000
# 25%     748.500000    436.179001    422.879486    430.445496    430.569489
# 50%    1496.000000   2387.610107   2178.500000   2269.889893   2286.409912
# 75%    2243.500000   8733.926948   8289.800459   8569.656494   8576.238715
# max    2991.000000  64863.098908  62208.964366  63523.754869  63503.457930
#
#              Volume     Marketcap
# count  2.991000e+03  2.991000e+03
# mean   1.090633e+10  1.208761e+11
# std    1.888895e+10  2.109438e+11
# min    0.000000e+00  7.784112e+08
# 25%    3.036725e+07  6.305579e+09
# 50%    9.460360e+08  3.741503e+10
# 75%    1.592015e+10  1.499957e+11
# ...

# %%
# Bitcoin.Date is the same as Bitcoin["Date"]
Bitcoin['Date'] = pd.to_datetime(Bitcoin['Date']) # changing Date from object to datetime64[ns]
print(Bitcoin.dtypes)
# Out:
# SNo                   int64
# Name                 object
# Symbol               object
# Date         datetime64[ns]
# High                float64
# Low                 float64
# Open                float64
# Close               float64
# Volume              float64
# Marketcap           float64
# dtype: object

# %%
Ethereum['Date'] = pd.to_datetime(Ethereum['Date']) # changing Date from object to datetime64[ns]
print(Ethereum.dtypes)
# Out:
# SNo                   int64
# Name                 object
# Symbol               object
# Date         datetime64[ns]
# High                float64
# Low                 float64
# Open                float64
# Close               float64
# Volume              float64
# Marketcap           float64
# dtype: object

# %%
plt.plot(Bitcoin.Date, Bitcoin.Close, linestyle='-', color='r')

plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gcf().autofmt_xdate()

plt.savefig('images/Bitcoin_price_over_time.png')
plt.show()
plt.close()

# %%
plt.plot(Ethereum.Date, Ethereum.Close, linestyle='-', color='b')

plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gcf().autofmt_xdate()

plt.savefig('images/Ethereum_price_over_time.png')
plt.show()
plt.close()

# %%
BTC = Bitcoin.iloc[:, 4:]
BTC
# Out:
#               High           Low          Open         Close        Volume  \
# 0       147.488007    134.000000    134.444000    144.539993  0.000000e+00
# 1       146.929993    134.050003    144.000000    139.000000  0.000000e+00
# 2       139.889999    107.720001    139.000000    116.989998  0.000000e+00
# 3       125.599998     92.281898    116.379997    105.209999  0.000000e+00
# 4       108.127998     79.099998    106.250000     97.750000  0.000000e+00
# ...            ...           ...           ...           ...           ...
# 2986  33939.588699  32770.680780  33549.600177  33897.048590  3.872897e+10
# 2987  34909.259899  33402.696536  33854.421362  34668.548402  2.438396e+10
# 2988  35937.567147  34396.477458  34665.564866  35287.779766  2.492431e+10
# 2989  35284.344430  33213.661034  35284.344430  33746.002456  2.672155e+10
# 2990  35038.536363  33599.916169  33723.509655  34235.193451  2.650126e+10
#
#          Marketcap
# 0     1.603769e+09
# 1     1.542813e+09
# ...

# %%
ETH = Ethereum.iloc[:, 4:]
ETH
# Out:
#              High          Low         Open        Close        Volume  \
# 0        2.798810     0.714725     2.793760     0.753325  6.741880e+05
# 1        0.879810     0.629191     0.706136     0.701897  5.321700e+05
# 2        0.729854     0.636546     0.713989     0.708448  4.052830e+05
# 3        1.131410     0.663235     0.708087     1.067860  1.463100e+06
# 4        1.289940     0.883608     1.058750     1.217440  2.150620e+06
# ...           ...          ...          ...          ...           ...
# 2155  2155.596496  2021.824808  2109.892677  2150.040364  3.179621e+10
# 2156  2237.567155  2117.590013  2150.835025  2226.114282  1.743336e+10
# 2157  2384.286857  2190.837703  2226.550382  2321.724112  1.878711e+10
# 2158  2321.922836  2163.041394  2321.922836  2198.582464  2.010379e+10
# 2159  2346.294874  2197.919385  2197.919385  2324.679449  2.089186e+10
#
#          Marketcap
# 0     4.548689e+07
# 1     4.239957e+07
# 2     4.281836e+07
# 3     6.456929e+07
# ...

# %%
import numpy as np
import itertools

# %%
corr_mat = np.corrcoef(BTC.T)
plt.figure()
plt.imshow(corr_mat, cmap='hot', interpolation='nearest') # body of the correlation matrix
plt.title('BTC Correlation Heatmap')                          # heading
plt.colorbar()                                            # the color spectrum on the right

thresh = 0.9      # setting the mid-point threshold -> for text color change/readability
for i, j in itertools.product(range(corr_mat.shape[0]), range(corr_mat.shape[1])):
    plt.text(j, i, format(corr_mat[i, j], '.2f'),                   # display corr coef, in 2 d.p. 
             horizontalalignment="center",
             color="black" if corr_mat[i, j] > thresh else "white") # change text color for easier reading
plt.savefig('images/Bitcoin_correlation_heatmap.png')
plt.show()
plt.close()

# %%
corr_mat = np.corrcoef(ETH.T)
plt.figure()
plt.imshow(corr_mat, cmap='hot', interpolation='nearest') # body of the correlation matrix
plt.title('ETH Correlation Heatmap')                          # heading
plt.colorbar()                                            # the color spectrum on the right

thresh = 0.9      # setting the mid-point threshold -> for text color change/readability
for i, j in itertools.product(range(corr_mat.shape[0]), range(corr_mat.shape[1])):
    plt.text(j, i, format(corr_mat[i, j], '.2f'),                   # display corr coef, in 2 d.p. 
             horizontalalignment="center",
             color="black" if corr_mat[i, j] > thresh else "white") # change text color for easier reading
plt.savefig('images/Bitcoin_correlation_heatmap.png')
plt.show()
plt.close()

# %%
# As expected, variables are highly correlated in Bitcoin dataset
    # High, Low, Open, Close, Volume, Marketcap
# Makes sense as they go hand in hand

# %%
'''
Make sure you have installed pyTorch prior to running the below code
There are several ways to achieve this:

    1. If your working environment is Anaconda_Navigator (Jupyter Notebook)
        1.1. Make sure the application is up to date 
            a.  Go to Environments -> 'Not Installed' -> Search 'PyTorch' and install the package
        Note: If application is faulty (in my case, does not boot), you need to reinstall the application
        Delete the directory where you stored anaconda3 and download new version: https://www.anaconda.com/download/success
        
    2. If your working environment is local terminal (Mac)
        2.1. Run this command in your terminal: pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
        NOTE: Latest PyTorch requires Python 3.8 or later. (Source: https://pytorch.org)


Below are some housekeeping python code to check if local system is up to date

import sys
print(sys.version) # 3.8 or above

import torch
print(torch.__version__) # check if package is installed
'''
# Out:
# "\nMake sure you have installed pyTorch prior to running the below code\nThere are several ways to achieve this:\n\n    1. If your working environment is Anaconda_Navigator (Jupyter Notebook)\n        1.1. Make sure the application is up to date \n            a.  Go to Environments -> 'Not Installed' -> Search 'PyTorch' and install the package\n        Note: If application is faulty (in my case, does not boot), you need to reinstall the application\n        Delete the directory where you stored anaconda3 and download new version: https://www.anaconda.com/download/success\n        \n    2. If your working environment is local terminal (Mac)\n        2.1. Run this command in your terminal: pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu\n        NOTE: Latest PyTorch requires Python 3.8 or later. (Source: https://pytorch.org)\n\n\nBelow are some housekeeping python code to check if local system is up to date\n\nimport sys\nprint(sys.version) # 
# ...

# %%
## Data Exploration: Sunspot

# About Data: Univariate Time Series

# %%
## Accessing Sunspot data
Sunspot = pd.read_csv('data/Sunspots.csv')
Sunspot.shape
# Out:
# (3265, 3)

# %%
Sunspot.head
# Out:
# <bound method NDFrame.head of       Unnamed: 0        Date  Monthly Mean Total Sunspot Number
# 0              0  1749-01-31                               96.7
# 1              1  1749-02-28                              104.3
# 2              2  1749-03-31                              116.7
# 3              3  1749-04-30                               92.8
# 4              4  1749-05-31                              141.7
# ...          ...         ...                                ...
# 3260        3260  2020-09-30                                0.6
# 3261        3261  2020-10-31                               14.4
# 3262        3262  2020-11-30                               34.0
# 3263        3263  2020-12-31                               21.8
# 3264        3264  2021-01-31                               10.4
#
# [3265 rows x 3 columns]>

# %%
plt.figure(figsize=(10, 6))
plt.plot(Sunspot['Monthly Mean Total Sunspot Number'], color='black', label='')
plt.xlabel('Months')
plt.ylabel('Sunspot Count')
plt.show()

# %%
Sunspot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3265 entries, 0 to 3264
# Data columns (total 3 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         3265 non-null   int64
#  1   Date                               3265 non-null   object
#  2   Monthly Mean Total Sunspot Number  3265 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 76.7+ KB

# %%
Sunspot['Date'] = pd.to_datetime(Sunspot['Date']) # changing Date from object to datetime64[ns]
print(Sunspot.dtypes)
# Out:
# Unnamed: 0                                    int64
# Date                                 datetime64[ns]
# Monthly Mean Total Sunspot Number           float64
# dtype: object

# %%
plt.plot(Sunspot['Date'], Sunspot['Monthly Mean Total Sunspot Number'], linestyle='-', color='orange')

plt.gca().xaxis.set_major_locator(mdates.YearLocator(base=50))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.gcf().autofmt_xdate()

plt.xlabel('Year')
plt.ylabel('Number of Sunspots')

plt.savefig('images/Sunspot.png')
plt.show()
plt.close()

# %%
response = Sunspot['Monthly Mean Total Sunspot Number']
response
# Out:
# 0        96.7
# 1       104.3
# 2       116.7
# 3        92.8
# 4       141.7
#         ...
# 3260      0.6
# 3261     14.4
# 3262     34.0
# 3263     21.8
# 3264     10.4
# Name: Monthly Mean Total Sunspot Number, Length: 3265, dtype: float64

# %%
# we are now ready to carry on with data modelling... (see other notebooks)

# %%
## Data Generation & Exploration: Mackey-Glass
# Generated chaotic univariate time series
# https://en.wikipedia.org/wiki/Mackey–Glass_equations

# If haven't installed the package, run the line below
# pip install reservoirpy

# %%
# https://reservoirpy.readthedocs.io/en/latest/api/generated/reservoirpy.datasets.mackey_glass.html
from reservoirpy.datasets import mackey_glass 

# Other values of tau can change the chaotic behaviour of the timeseries
data = mackey_glass(n_timesteps = 3000, tau=17, a=0.2, b=0.1, n=10, x0=1.2, h=1.0, seed=5925)

# %%
# Plot the time series
plt.figure(figsize=(10, 6))
plt.plot(data)
plt.title('Mackey-Glass Time Series')
plt.xlabel('Time Steps')
plt.ylabel('x(t)')
plt.grid()
plt.show()

# %%
data = data.flatten()
data = pd.Series(data, name='Response')

# Set the index to be a range of integers
data.index = range(len(data))
# Print or inspect the Series
print(data)
# Out:
# 0       1.200000
# 1       1.121747
# 2       1.035093
# 3       0.959023
# 4       0.912713
#           ...
# 2995    1.005424
# 2996    0.945231
# 2997    0.886766
# 2998    0.830784
# 2999    0.777740
# Name: Response, Length: 3000, dtype: float64

# %%
# Data is now ready to fit models (see other notebooks)

# %%
## Data Generation & Exploration: Lorenz

# Generated chaotic univariate time series

# %%
# https://en.wikipedia.org/wiki/Lorenz_system
def lorenz(xyz, *, s=10, r=28, b=2.667):
    """
    Parameters
    ----------
    xyz : array-like, shape (3,)
       Point of interest in three-dimensional space.
    s, r, b : float
       Parameters defining the Lorenz attractor.

    Returns
    -------
    xyz_dot : array, shape (3,)
       Values of the Lorenz attractor's partial derivatives at *xyz*.
    """
    x, y, z = xyz
    x_dot = s*(y - x)
    y_dot = r*x - y - x*z
    z_dot = x*y - b*z
    return np.array([x_dot, y_dot, z_dot])

# %%
dt = 0.01
num_steps = 10000

xyzs = np.empty((num_steps + 1, 3))  # Need one more for the initial values
xyzs[0] = (0., 1., 1.05)  # Set initial values
# Step through "time", calculating the partial derivatives at the current point
# and using them to estimate the next point
for i in range(num_steps):
    xyzs[i + 1] = xyzs[i] + lorenz(xyzs[i]) * dt

# %%
# Plot
ax = plt.figure().add_subplot(projection='3d')

ax.plot(*xyzs.T, lw=0.6)
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")
ax.set_title("Lorenz Attractor")

plt.show()

# %%
xyzs
# Out:
# array([[ 0.        ,  1.        ,  1.05      ],
#        [ 0.1       ,  0.99      ,  1.0219965 ],
#        [ 0.189     ,  1.007078  ,  0.99572985],
#        ...,
#        [ 8.77456852, 13.39169112, 19.84783236],
#        [ 9.23628078, 13.97309174, 20.49355378],
#        [ 9.70996188, 14.52667728, 21.23758469]])

# %%
# need to split into multiple univariate time series, perform corresponding predictions

# %%
# Plot the time series
plt.figure(figsize=(12, 6))

# Plot each dimension of the Lorenz attractor
plt.subplot(3, 1, 1)
plt.plot(xyzs[:, 0])
plt.title('Lorenz Time Series - X Dimension')
plt.xlabel('Time Steps')
plt.ylabel('X')

plt.subplot(3, 1, 2)
plt.plot(xyzs[:, 1])
plt.title('Lorenz Time Series - Y Dimension')
plt.xlabel('Time Steps')
plt.ylabel('Y')

plt.subplot(3, 1, 3)
plt.plot(xyzs[:, 2])
plt.title('Lorenz Time Series - Z Dimension')
plt.xlabel('Time Steps')
plt.ylabel('Z')

plt.tight_layout()
plt.show()
