# %%
# Import Libraries
import time
start_time = time.time() # begin time
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
Bitcoin = pd.read_csv('../../data/bitcoin.csv')
# Bitcoin = Bitcoin.drop(columns=['Adj Close'])
Ethereum = pd.read_csv('../../data/ethereum.csv')
# Ethereum = Ethereum.drop(columns=['Adj Close'])

# %%
# Understand Data

# %%
Bitcoin
# Out:
#             Date          Open          High           Low         Close  \
# 0     2014-09-18    456.859985    456.859985    413.104004    424.440002
# 1     2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2     2014-09-20    394.673004    423.295990    389.882996    408.903992
# 3     2014-09-21    408.084991    412.425995    393.181000    398.821014
# 4     2014-09-22    399.100006    406.915985    397.130005    402.152008
# ...          ...           ...           ...           ...           ...
# 3406  2024-01-15  41715.066406  43319.722656  41705.417969  42511.968750
# 3407  2024-01-16  42499.335938  43566.273438  42085.996094  43154.945313
# 3408  2024-01-17  43132.101563  43189.890625  42189.308594  42742.652344
# 3409  2024-01-18  42742.312500  42876.347656  40631.171875  41262.058594
# 3410  2024-01-19  41278.460938  42134.160156  40297.457031  41618.406250
#
#          Adj Close       Volume
# 0       424.440002     34483200
# 1       394.795990     37919700
# 2       408.903992     36863600
# 3       398.821014     26580100
# 4       402.152008     24127600
# ...            ...          ...
# 3406  42511.968750  22320220558
# 3407  43154.945313  24062872740
# 3408  42742.652344  20851232595
# 3409  41262.058594  25218357242
# 3410  41618.406250  25752407154
#
# [3411 rows x 7 columns]

# %%
Bitcoin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3411 entries, 0 to 3410
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3411 non-null   object
#  1   Open       3411 non-null   float64
#  2   High       3411 non-null   float64
#  3   Low        3411 non-null   float64
#  4   Close      3411 non-null   float64
#  5   Adj Close  3411 non-null   float64
#  6   Volume     3411 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 186.7+ KB

# %%
# No null values

# %%
Ethereum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2262 entries, 0 to 2261
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2262 non-null   object
#  1   Open       2262 non-null   float64
#  2   High       2262 non-null   float64
#  3   Low        2262 non-null   float64
#  4   Close      2262 non-null   float64
#  5   Adj Close  2262 non-null   float64
#  6   Volume     2262 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 123.8+ KB

# %%
Ethereum
# Out:
#             Date         Open         High          Low        Close  \
# 0     2017-11-10   320.670990   324.717987   294.541992   299.252991
# 1     2017-11-11   298.585999   319.453003   298.191986   314.681000
# 2     2017-11-12   314.690002   319.153015   298.513000   307.907990
# 3     2017-11-13   307.024994   328.415009   307.024994   316.716003
# 4     2017-11-14   316.763000   340.177002   316.763000   337.631012
# ...          ...          ...          ...          ...          ...
# 2257  2024-01-15  2471.666992  2550.769043  2470.820801  2511.363770
# 2258  2024-01-16  2510.627197  2613.566895  2500.003906  2587.691162
# 2259  2024-01-17  2587.044678  2592.737061  2508.432861  2528.369385
# 2260  2024-01-18  2528.593262  2546.263916  2426.135498  2467.018799
# 2261  2024-01-19  2468.688965  2501.305176  2414.710938  2489.498535
#
#         Adj Close       Volume
# 0      299.252991    885985984
# 1      314.681000    842300992
# 2      307.907990   1613479936
# 3      316.716003   1041889984
# 4      337.631012   1069680000
# ...           ...          ...
# 2257  2511.363770   9700630000
# 2258  2587.691162  11063317095
# 2259  2528.369385  10441017520
# 2260  2467.018799  11900028080
# 2261  2489.498535  11405278376
#
# [2262 rows x 7 columns]

# %%
Bitcoin.Close # currency is in USD
# Out:
# 0         424.440002
# 1         394.795990
# 2         408.903992
# 3         398.821014
# 4         402.152008
#             ...
# 3406    42511.968750
# 3407    43154.945313
# 3408    42742.652344
# 3409    41262.058594
# 3410    41618.406250
# Name: Close, Length: 3411, dtype: float64

# %%
Bitcoin.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count   3411.000000   3411.000000   3411.000000   3411.000000   3411.000000
# mean   14739.467044  15084.010402  14368.140797  14750.235819  14750.235819
# std    16289.496856  16680.173273  15851.362284  16291.266521  16291.266521
# min      176.897003    211.731003    171.509995    178.102997    178.102997
# 25%      921.513000    932.895508    907.335998    921.689514    921.689514
# 50%     8286.879883   8458.453125   8105.252930   8277.009766   8277.009766
# 75%    24327.469726  24949.477539  23870.385742  24351.801758  24351.801758
# max    67549.734375  68789.625000  66382.062500  67566.828125  67566.828125
#
#              Volume
# count  3.411000e+03
# mean   1.663183e+10
# std    1.907865e+10
# min    5.914570e+06
# 25%    1.681380e+08
# 50%    1.180170e+10
# 75%    2.698524e+10
# max    3.509679e+11

# %%
Ethereum.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2262.000000  2262.000000  2262.000000  2262.000000  2262.000000
# mean   1247.673093  1283.448150  1208.296582  1248.432560  1248.432560
# std    1118.787880  1150.906857  1082.478178  1118.520649  1118.520649
# min      84.279694    85.342743    82.829887    84.308296    84.308296
# 25%     231.631092   236.656848   227.089447   231.802292   231.802292
# 50%    1036.978333  1089.664978   951.205506  1038.645813  1038.645813
# 75%    1870.895599  1905.327210  1843.535065  1871.595367  1871.595367
# max    4810.071289  4891.704590  4718.039063  4812.087402  4812.087402
#
#              Volume
# count  2.262000e+03
# mean   1.205547e+10
# std    1.012564e+10
# min    6.217330e+08
# 25%    4.845385e+09
# 50%    9.403389e+09
# 75%    1.657534e+10
# max    8.448291e+10

# %%
# Bitcoin.Date is the same as Bitcoin["Date"]
Bitcoin['Date'] = pd.to_datetime(Bitcoin['Date']) # changing Date from object to datetime64[ns]
print(Bitcoin.dtypes)
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
Ethereum['Date'] = pd.to_datetime(Ethereum['Date']) # changing Date from object to datetime64[ns]
print(Ethereum.dtypes)
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
plt.plot(Bitcoin.Date, Bitcoin.Close, linestyle='-', color='r')

plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.xlabel("Year")
plt.ylabel("Price (USD)")
plt.savefig('bitcoin.png')
plt.show()
plt.close()

# %%
plt.plot(Ethereum.Date, Ethereum.Close, linestyle='-', color='b')
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.xlabel("Year")
plt.ylabel("Price (USD)")
plt.savefig('ethereum.png')
plt.show()
plt.close()

# %%
BTC = Bitcoin.iloc[:, 1:]
BTC
# Out:
#               Open          High           Low         Close     Adj Close  \
# 0       456.859985    456.859985    413.104004    424.440002    424.440002
# 1       424.102997    427.834991    384.532013    394.795990    394.795990
# 2       394.673004    423.295990    389.882996    408.903992    408.903992
# 3       408.084991    412.425995    393.181000    398.821014    398.821014
# 4       399.100006    406.915985    397.130005    402.152008    402.152008
# ...            ...           ...           ...           ...           ...
# 3406  41715.066406  43319.722656  41705.417969  42511.968750  42511.968750
# 3407  42499.335938  43566.273438  42085.996094  43154.945313  43154.945313
# 3408  43132.101563  43189.890625  42189.308594  42742.652344  42742.652344
# 3409  42742.312500  42876.347656  40631.171875  41262.058594  41262.058594
# 3410  41278.460938  42134.160156  40297.457031  41618.406250  41618.406250
#
#            Volume
# 0        34483200
# 1        37919700
# 2        36863600
# 3        26580100
# 4        24127600
# ...           ...
# 3406  22320220558
# 3407  24062872740
# 3408  20851232595
# 3409  25218357242
# 3410  25752407154
#
# [3411 rows x 6 columns]

# %%
ETH = Ethereum.iloc[:, 1:]
ETH
# Out:
#              Open         High          Low        Close    Adj Close  \
# 0      320.670990   324.717987   294.541992   299.252991   299.252991
# 1      298.585999   319.453003   298.191986   314.681000   314.681000
# 2      314.690002   319.153015   298.513000   307.907990   307.907990
# 3      307.024994   328.415009   307.024994   316.716003   316.716003
# 4      316.763000   340.177002   316.763000   337.631012   337.631012
# ...           ...          ...          ...          ...          ...
# 2257  2471.666992  2550.769043  2470.820801  2511.363770  2511.363770
# 2258  2510.627197  2613.566895  2500.003906  2587.691162  2587.691162
# 2259  2587.044678  2592.737061  2508.432861  2528.369385  2528.369385
# 2260  2528.593262  2546.263916  2426.135498  2467.018799  2467.018799
# 2261  2468.688965  2501.305176  2414.710938  2489.498535  2489.498535
#
#            Volume
# 0       885985984
# 1       842300992
# 2      1613479936
# 3      1041889984
# 4      1069680000
# ...           ...
# 2257   9700630000
# 2258  11063317095
# 2259  10441017520
# 2260  11900028080
# 2261  11405278376
#
# [2262 rows x 6 columns]

# %%
corr_mat = BTC.corr()
vmin = corr_mat.values.min()
vmax = corr_mat.values.max()
# Plot with seaborn
plt.figure()
sns.heatmap(
    corr_mat,
    annot=True,              # show correlation coefficients
    fmt=".2f",               # 2 decimal places
    cmap="RdBu_r",           # blue = low, red = high
    center=0,                # center colormap at 0
    vmin=vmin, vmax=vmax,         # full correlation scale
    cbar_kws={"shrink": .8}  # shrink colorbar
)

plt.title("BTC Correlation Heatmap")
plt.yticks(rotation=0)               # keep y-axis labels horizontal
plt.tight_layout()
plt.savefig("btc_correlation_heatmap.png", dpi=300, bbox_inches="tight")
plt.show()
plt.close()

# %%
corr_mat = ETH.corr()
vmin = corr_mat.values.min()
vmax = corr_mat.values.max()
# Plot with seaborn
plt.figure()
sns.heatmap(
    corr_mat,
    annot=True,              # show correlation coefficients
    fmt=".2f",               # 2 decimal places
    cmap="RdBu_r",           # blue = low, red = high
    center=0,                # center colormap at 0
    vmin=vmin, vmax=vmax,         # full correlation scale
    cbar_kws={"shrink": .8}  # shrink colorbar
)

plt.title("ETH Correlation Heatmap")
plt.yticks(rotation=0)               # keep y-axis labels horizontal
plt.tight_layout()
plt.savefig("eth_correlation_heatmap.png", dpi=300, bbox_inches="tight")
plt.show()
plt.close()

# %%
# As expected, variables are highly correlated in Bitcoin dataset
    # High, Low, Open, Close, Volume, Marketcap
# Makes sense as they go hand in hand

# Variables are highly correlated to each other, this makes them redunctant and noisy which can affect prediction accuracy
# It will not be surprising for multivariate models to perform worse than univariate models

# %%
'''
Make sure you have installed pyTorch prior to running the below code
There are several ways to achieve this:

    1. If your working environment is Anaconda_Navigator (Jupyter Notebook)
        1.1. Make sure the application is up to date 
            a.  Go to Environments -> 'Not Installed' -> Search 'PyTorch' and install the package
        Note: If application is faulty (in my case, does not boot), you need to reinstall the application
        Delete the directory where you stored anaconda3 and download new version: https://www.anaconda.com/download/success
        
    2. If your working environment is local terminal (Mac)
        2.1. Run this command in your terminal: pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
        NOTE: Latest PyTorch requires Python 3.8 or later. (Source: https://pytorch.org)


Below are some housekeeping python code to check if local system is up to date

import sys
print(sys.version) # 3.8 or above

import torch
print(torch.__version__) # check if package is installed
'''
# Out:
# "\nMake sure you have installed pyTorch prior to running the below code\nThere are several ways to achieve this:\n\n    1. If your working environment is Anaconda_Navigator (Jupyter Notebook)\n        1.1. Make sure the application is up to date \n            a.  Go to Environments -> 'Not Installed' -> Search 'PyTorch' and install the package\n        Note: If application is faulty (in my case, does not boot), you need to reinstall the application\n        Delete the directory where you stored anaconda3 and download new version: https://www.anaconda.com/download/success\n        \n    2. If your working environment is local terminal (Mac)\n        2.1. Run this command in your terminal: pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu\n        NOTE: Latest PyTorch requires Python 3.8 or later. (Source: https://pytorch.org)\n\n\nBelow are some housekeeping python code to check if local system is up to date\n\nimport sys\nprint(sys.version) # 3.8 or above\n\nimport torch\nprint(torch.__version__) # check if package is installed\n"

# %%
## Data Exploration: Sunspot

# About Data: Univariate Time Series
# https://www.kaggle.com/datasets/robervalt/sunspots

# %%
## Accessing Sunspot data
Sunspot = pd.read_csv('../../data/sunspots.csv')
Sunspot.shape
# Out:
# (3265, 3)

# %%
Sunspot.head
# Out:
# <bound method NDFrame.head of       Unnamed: 0        Date  Monthly Mean Total Sunspot Number
# 0              0  1749-01-31                               96.7
# 1              1  1749-02-28                              104.3
# 2              2  1749-03-31                              116.7
# 3              3  1749-04-30                               92.8
# 4              4  1749-05-31                              141.7
# ...          ...         ...                                ...
# 3260        3260  2020-09-30                                0.6
# 3261        3261  2020-10-31                               14.4
# 3262        3262  2020-11-30                               34.0
# 3263        3263  2020-12-31                               21.8
# 3264        3264  2021-01-31                               10.4
#
# [3265 rows x 3 columns]>

# %%
Sunspot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3265 entries, 0 to 3264
# Data columns (total 3 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         3265 non-null   int64
#  1   Date                               3265 non-null   object
#  2   Monthly Mean Total Sunspot Number  3265 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 76.7+ KB

# %%
Sunspot['Date'] = pd.to_datetime(Sunspot['Date']) # changing Date from object to datetime64[ns]
print(Sunspot.dtypes)
# Out:
# Unnamed: 0                                    int64
# Date                                 datetime64[ns]
# Monthly Mean Total Sunspot Number           float64
# dtype: object

# %%
plt.plot(Sunspot['Date'], Sunspot['Monthly Mean Total Sunspot Number'], linestyle='-', color='orange')

plt.gca().xaxis.set_major_locator(mdates.YearLocator(base=50))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

plt.xlabel('Year')
plt.ylabel('No. of Sunspots Observed')

plt.savefig('sunspots.png')
plt.show()
plt.close()

# %%
# Their number varies according to the approximately 11-year solar cycle.
# Source: https://en.wikipedia.org/wiki/Sunspot

# %%
response = Sunspot['Monthly Mean Total Sunspot Number']
response
# Out:
# 0        96.7
# 1       104.3
# 2       116.7
# 3        92.8
# 4       141.7
#         ...
# 3260      0.6
# 3261     14.4
# 3262     34.0
# 3263     21.8
# 3264     10.4
# Name: Monthly Mean Total Sunspot Number, Length: 3265, dtype: float64

# %%
# we are now ready to carry on with data modelling... (see other notebooks)

# %%
## Data Generation & Exploration: Mackey-Glass
# Generated chaotic univariate time series
# https://en.wikipedia.org/wiki/Mackey–Glass_equations

# If haven't installed the package, run the line below
# pip install reservoirpy

# %%
# https://reservoirpy.readthedocs.io/en/latest/api/generated/reservoirpy.datasets.mackey_glass.html
# An equation of Mackey-Glass delayed differential equation is attached there
from reservoirpy.datasets import mackey_glass 

# Other values of tau can change the chaotic behaviour of the timeseries: default = 17
data = mackey_glass(n_timesteps = 3000, tau=75, a=0.2, b=0.1, n=10, x0=1.2, h=1.0, seed=5925)

# %%
# Plot the time series
plt.figure(figsize=(10, 6))
plt.plot(data)
plt.title('Mackey-Glass Time Series')
plt.xlabel('Time Steps')
plt.ylabel('x(t)')
plt.grid()
plt.savefig('mackey-glass.png')
plt.show()
plt.close()

# %%
data = data.flatten()
data = pd.Series(data, name='Response')

# Set the index to be a range of integers
data.index = range(len(data))
# Print or inspect the Series
print(data)
# Out:
# 0       1.200000
# 1       1.121747
# 2       1.035093
# 3       0.959023
# 4       0.912713
#           ...
# 2995    1.330521
# 2996    1.315928
# 2997    1.285884
# 2998    1.243242
# 2999    1.193454
# Name: Response, Length: 3000, dtype: float64

# %%
# Data is now ready to fit models (see other notebooks)

# %%
## Data Generation & Exploration: Lorenz

# Generated chaotic univariate time series

# %%
# https://en.wikipedia.org/wiki/Lorenz_system
def lorenz(xyz, *, s=10, r=28, b=2.667):
    """
    Parameters
    ----------
    xyz : array-like, shape (3,)
       Point of interest in three-dimensional space.
    s, r, b : float
       Parameters defining the Lorenz attractor.

    Returns
    -------
    xyz_dot : array, shape (3,)
       Values of the Lorenz attractor's partial derivatives at *xyz*.
    """
    x, y, z = xyz
    x_dot = s*(y - x)
    y_dot = r*x - y - x*z
    z_dot = x*y - b*z
    return np.array([x_dot, y_dot, z_dot])

# %%
dt = 0.01
num_steps = 3000

xyzs = np.empty((num_steps + 1, 3))  # Need one more for the initial values
xyzs[0] = (0., 1., 1.05)  # Set initial values
# Step through "time", calculating the partial derivatives at the current point
# and using them to estimate the next point
for i in range(num_steps):
    xyzs[i + 1] = xyzs[i] + lorenz(xyzs[i]) * dt

# %%
# Plot
ax = plt.figure().add_subplot(projection='3d')

ax.plot(*xyzs.T, lw=0.6)
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")
ax.set_title("Lorenz Attractor")
plt.savefig('lorenz-3D.png')
plt.show()
plt.close()

# %%
xyzs
# Out:
# array([[ 0.        ,  1.        ,  1.05      ],
#        [ 0.1       ,  0.99      ,  1.0219965 ],
#        [ 0.189     ,  1.007078  ,  0.99572985],
#        ...,
#        [-3.77294581,  0.35337428, 27.71782879],
#        [-3.3603138 ,  0.33919437, 26.96526167],
#        [-2.99036298,  0.30103197, 26.23470015]])

# %%
# need to split into multiple univariate time series, perform corresponding predictions

# %%
# Plot the time series
plt.figure(figsize=(12, 6))

# Plot each dimension of the Lorenz attractor
plt.subplot(3, 1, 1)
plt.plot(xyzs[:, 0])
plt.title('Lorenz Time Series - X Dimension')
plt.xlabel('Time Steps')
plt.ylabel('X')

plt.subplot(3, 1, 2)
plt.plot(xyzs[:, 1])
plt.title('Lorenz Time Series - Y Dimension')
plt.xlabel('Time Steps')
plt.ylabel('Y')

plt.subplot(3, 1, 3)
plt.plot(xyzs[:, 2])
plt.title('Lorenz Time Series - Z Dimension')
plt.xlabel('Time Steps')
plt.ylabel('Z')

plt.tight_layout()
plt.savefig('lorenz-xyz.png')
plt.show()
plt.close()

# %%
end_time = time.time() # end time
start_str = time.strftime("%H:%M:%S", time.localtime(start_time)) # e.g. 20:34:31
end_str = time.strftime("%H:%M:%S", time.localtime(end_time)) # e.g. 20:35:41

# %%
elapsed = end_time - start_time # Calculate execution time
minutes = int(elapsed // 60)
seconds = int(elapsed % 60)

# %%
print("Time Performance")
print(f"	The models began running from {start_str} and ended at {end_str}")
print(f"	Execution time: {minutes} minutes {seconds} seconds")
# Out:
# Time Performance
# 	The models began running from 13:26:31 and ended at 13:26:36
# 	Execution time: 0 minutes 5 seconds
